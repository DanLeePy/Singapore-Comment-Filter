# %%
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
class TimeoutException(Exception): pass
import pandas as pd

###################################################   

# make chrome incognito and headless to run faster
options = webdriver.ChromeOptions()
options.add_argument('--incognito')
options.add_argument('--headless')

# change the driver_path to wherever your webdriver is located
driver_path = "C:/Users/Quan Hao/Downloads/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(executable_path=driver_path, options=options)

# go to HardWareZone website
driver.get("https://forums.hardwarezone.com.sg/eat-drink-man-woman-16/")

threads_list = []

# get a list of threads
while True:
    try:
        # find the thread links
        thread_link = driver.find_elements_by_xpath("//*[contains(@id,'thread_title_')]")
        for k in thread_link:
            threads_list.append(k.get_attribute("href"))
            
        #keeps clicking the Next button to the end
        count = 0
        while count < 4:
            next_button = wait_time.until(EC.visibility_of_element_located((By.XPATH,"//*[contains(@title,'Next Page - Results')]")))
            next_button.send_keys(webdriver.common.keys.Keys.RETURN)
            count+=1
    except Exception:
        break

# websites = ['https://forums.hardwarezone.com.sg/eat-drink-man-woman-16/sinkie-aunty-buy-2nd-hand-expect-customer-service-tio-suan-5992451.html',
#             'https://forums.hardwarezone.com.sg/eat-drink-man-woman-16/do-you-remove-your-ring-when-you-going-eat-cheekon-5992476.html']

###################################################   

posts_list =[]

wait_time = WebDriverWait(driver, 15)

for i in threads_list:
    driver.get(i)
    
    while True:
        try:
            #find the comments
            #posts = driver.find_elements_by_xpath("//*[contains(@id,'post_message_')]")
            posts = driver.find_elements_by_xpath("//div[contains(@class,'post_message')]")
            #posts = wait_time.until(EC.presence_of_all_elements_located((By.XPATH, "//*[contains(@id,'post_message_')]")))
            for j in posts:
                posts_list.append(j.text)

            #keeps clicking the Next button to the end
            next_button = wait_time.until(EC.visibility_of_element_located((By.XPATH,"//*[contains(@title,'Next Page - Results')]")))
            next_button.send_keys(webdriver.common.keys.Keys.RETURN)
        except Exception:
            break

###################################################        

posts_list2 =[]
for i in posts_list:
    t = i.replace('\n','')
    posts_list2.append(t)
#print(posts_list2)

df = pd.DataFrame(posts_list2, columns=['Thread Title'])
#print(df)

df.to_csv("Scraped_HWZ_Comments.csv", index=False)
print("Scraped completed")

driver.close()
# Out:
#                                             Thread Title
# 0      For those interested to get alerts whenever th...
# 1                                Thanks, very handy cum.
# 2      threadstarter wrote:Thanks, very handy cum.You...
# 3                                            ok noted...
# 4                                thanks for the heads up
# 5      Best is come here for latest breakdownDont tru...
# 6      ImFromPipiForum wrote:Best is come here for la...
# 7                                              Buy a car
# 8      How come today stations no mrt arriving minute...
# 9      Yea . Here very updated one. As long as more t...
# 10     midnightpapa wrote:How come today stations no ...
# 11     chenaz wrote:Yea . Here very updated one. As l...
# 12     neojudy wrote:Buy a carNot everyone can afford...
# 13                                I sit car dein comfort
# 14     Wow shiat is getting real when this thread got...
# 15     Maybe it's TS app rehBananaMilkShake wrote:Wow...
# 16     BananaMilkShake wrote:Wow shiat is getting rea...
# 17     Travis_Touchdown wrote:Might as well sticky th...
# 18                                              Thank...
# 19     you know the transport is **** when there's an...
# 20     I have updated the first post with other resou...
# 21     Will ah cow come after ts or notch....rike tat...
# 22                             TS I ish take bus one leh
# 23     circle line was stucked for 5min. now intermit...
# 24     BananaMilkShake wrote:Wow shiat is getting rea...
# 25     This image has been resized.Click to view orig...
# 26     neojudy wrote:Why promoted. I also dun underst...
# 27     neojudy wrote:Buy a carBuy a carPosted with qu...
# 28     The_Davis wrote:TS I ish take bus one lehI hav...
# 29     ceecookie wrote:This image has been resized.Cl...
# ...                                                  ...
# 27535  Complete ur 18 gor li holes or not?MianBaoFren...
# 27536  Knight_Rider wrote:Quick declare your love for...
# 27537  kleong wrote:Ah gui rejected liao. Pan Pan wan...
# 27538  DOMHO7 wrote:KR tonight hoot tolok ahSent from...
# 27539  Ruoyenne wrote:Complete ur 18 gor li holes or ...
# 27540  I shy... watching u and pick gor Lee for chiu ...
# 27541  Ruoyenne wrote:I shy... watching u and pick go...
# 27542  Ruoyenne wrote:Complete ur 18 gor li holes or ...
# 27543  Knight_Rider wrote:https://www.bluelotus.com.s...
# 27544  Eh.. lazy ish watch u Pak from far.. dun even ...
# 27545  I pick gor lee only Boss Dom.. sometimes prete...
# 27546  Ruoyenne wrote:Eh.. lazy ish watch u Pak from ...
# 27547  Ruoyenne wrote:Eh.. lazy ish watch u Pak from ...
# 27548  https://cityvoiceng.com/most-girls-l...-day-sa...
# 27549                   5 years today, exactly this date
# 27550                                 Nov babies welcome
# 27551  Making baby nao!Sent from Old Man Pressing On ...
# 27552               ccb the hotels are all full already!
# 27553  Beh-Hawk wrote:ccb the hotels are all full alr...
# 27554  Beh-Hawk wrote:ccb the hotels are all full alr...
# 27555               what to do? Every guy also like OCBC
# 27556  PleaseDontBanMe wrote:Me and my bf going geyla...
# 27557  Surveys also show that BBFAs lose their virgin...
# 27558  This image has been resized.Click to view orig...
# 27559  Those of u who have daughters above 13 years o...
# 27560  tomorrow in office sure see many OLs cant walk...
# 27561  Most edmwers are BBFA, so don't really concern...
# 27562  mirukuboi wrote:tomorrow in office sure see ma...
# 27563  mirukuboi wrote:tomorrow in office sure see ma...
# 27564  PleaseDontBanMe wrote:Me and my bf going geyla...
#
# [27565 rows x 1 columns]
# Scraped completed
